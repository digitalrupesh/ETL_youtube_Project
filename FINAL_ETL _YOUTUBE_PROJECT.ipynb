# %% [markdown]
# # Extracting data from CSV FILE

# %%
import pandas as pd

# %%
ca=pd.read_csv("C:\\Users\\rupes\\Downloads\\archive\\CAvideos.csv")
us=pd.read_csv("C:\\Users\\rupes\\Downloads\\archive\\USvideos.csv")

# %%
print(ca.columns)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
print(us.columns)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
ca.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
us.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %% [markdown]
# # Adding country column and cleaning Data

# %%
ca = pd.read_csv("C:\\Users\\rupes\\Downloads\\archive\\CAvideos.csv", usecols = ['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'])

# %%
ca.insert(1,'country','CA')
ca
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 ca.insert(1,'country','CA')
#       2 ca
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4807, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4801     raise ValueError(
#    4802         "Cannot specify 'allow_duplicates=True' when "
#    4803         "'self.flags.allows_duplicate_labels' is False."
#    4804     )
#    4805 if not allow_duplicates and column in self.columns:
#    4806     # Should this be a different kind of error??
# -> 4807     raise ValueError(f"cannot insert {column}, already exists")
#    4808 if not isinstance(loc, int):
#    4809     raise TypeError("loc must be int")
#
# ValueError: cannot insert country, already exists

# %%
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40876  sGolxsMSGfQ      CA      18.14.06
# 40877  8HNuRNi8t70      CA      18.14.06
# 40878  GWlKEM3m2EE      CA      18.14.06
# 40879  lbMKLzQ4cNQ      CA      18.14.06
# 40880  POTgw38-m58      CA      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...

# %%
us = pd.read_csv("C:\\Users\\rupes\\Downloads\\archive\\USvideos.csv", usecols = ['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'])

# %%
us.insert(1,'country','US')
us
# Out:
#           video_id country trending_date  \
# 0      2kyS6SvSYSE      US      17.14.11
# 1      1ZAPwfrtAFY      US      17.14.11
# 2      5qpjK5DgCt4      US      17.14.11
# 3      puqaWrEC7tY      US      17.14.11
# 4      d380meD0W0M      US      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %%
ca.to_csv('CA_Youtube_videos1.csv',index=False,header=True )
us.to_csv('US_Youtube_videos1.csv',index=False,header=True )

df = pd.concat(map(pd.read_csv, ['CA_Youtube_videos1.csv', 'US_Youtube_videos1.csv']))

# %%
df
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %% [markdown]
# # Importing Json file

# %%
import json
from pandas.io.json import json_normalize
cat=[]

# %%
c = pd.read_json(r"C:\Users\rupes\Downloads\archive\CA_category_id.json")
u = pd.read_json(r"C:\Users\rupes\Downloads\archive\US_category_id.json")

# %%
c
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# ...

# %%
u
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# ...

# %% [markdown]
# # Transforming

# %%
countries = [r"C:\Users\rupes\Downloads\archive\CA_category_id.json",r"C:\Users\rupes\Downloads\archive\US_category_id.json"]

# %%
for country in countries:
    c=json.load(open(country, 'r'))
    for data in c['items']:
        cat.append([data['id'],country[3:5],data['snippet']['title']])
            
cat
# Out:
# [['1', 'Us', 'Film & Animation'],
#  ['2', 'Us', 'Autos & Vehicles'],
#  ['10', 'Us', 'Music'],
#  ['15', 'Us', 'Pets & Animals'],
#  ['17', 'Us', 'Sports'],
#  ['18', 'Us', 'Short Movies'],
#  ['19', 'Us', 'Travel & Events'],
#  ['20', 'Us', 'Gaming'],
#  ['21', 'Us', 'Videoblogging'],
#  ['22', 'Us', 'People & Blogs'],
#  ['23', 'Us', 'Comedy'],
#  ['24', 'Us', 'Entertainment'],
#  ['25', 'Us', 'News & Politics'],
#  ['26', 'Us', 'Howto & Style'],
#  ['27', 'Us', 'Education'],
#  ['28', 'Us', 'Science & Technology'],
#  ['30', 'Us', 'Movies'],
#  ['31', 'Us', 'Anime/Animation'],
#  ['32', 'Us', 'Action/Adventure'],
#  ['33', 'Us', 'Classics'],
#  ['34', 'Us', 'Comedy'],
#  ['35', 'Us', 'Documentary'],
#  ['36', 'Us', 'Drama'],
#  ['37', 'Us', 'Family'],
#  ['38', 'Us', 'Foreign'],
#  ['39', 'Us', 'Horror'],
#  ['40', 'Us', 'Sci-Fi/Fantasy'],
#  ['41', 'Us', 'Thriller'],
#  ['42', 'Us', 'Shorts'],
#  ['43', 'Us', 'Shows'],
#  ['44', 'Us', 'Trailers'],
# ...

# %% [markdown]
# # Mapping Category name

# %%
categoryCA_map={1:'Film & Animation', 2:'Autos & Vehicles', 10:'Music', 15:'Pets & Animals', 17:'Sports',18: 'Short Movies',
               19:'Travel & Events', 20:'Gaming',21: 'Videoblogging',22: 'People & Blogs',23: 'Comedy',24: 'Entertainment',
               25: 'News & Politics',26: 'Howto & Style',27: 'Education', 28: 'Science & Technology',29: 'Nonprofits & Activism',30: 'Movies', 
               31: 'Anime/Animation', 32: 'Action/Adventure',33: 'Classics', 34:'Comedy', 35: 'Documentary', 36: 'Drama',
               37: 'Family', 38: 'Foreign', 39: 'Horror', 40: 'Sci-Fi/Fantasy', 41: 'Thriller', 42: 'Shorts', 43: 'Shows', 44: 'Trailers'}

df['category_name']=df['category_id'].map(categoryCA_map)

# %%
df
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %%
c2=df.loc[:, ['video_id','country', 'trending_date', 'title','channel_title', 'category_id','category_name', 'publish_time',
                           'views', 'likes','dislikes', 'comment_count']]

# %%
df=c2

# %%
df
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %% [markdown]
# # Loading Dataframe to Mysql

# %%
import csv
import pandas as pd
from sqlalchemy import create_engine, types

engine = create_engine("mysql+mysqldb://root:Rupesh12345@localhost/youtube") # enter your password and database names here
#df = pd.read_csv(r"C:\Users\rupes\Downloads\etl_project-main\etl_project-main\final_youtube_videos.csv",sep=',',quotechar='\'',encoding='utf8') # Replace Excel_file_name with your excel sheet name

df.to_sql('youtube_videos_db',con=engine,index=False,if_exists='append') # Replace Table_name with your sql table name
# Out:
# 81830

# %%
df
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %%
import pandas as pd
import pandasql as ps
ps.sqldf("select * from df WHERE category_id>30" )
# Out:
#         video_id country trending_date  \
# 0    AlrbKKGIcjI      CA      17.15.11
# 1    mQbsY2KTFHk      CA      17.15.11
# 2    QfmIUoZej9Q      CA      17.16.11
# 3    5EBDXsTkg1E      CA      17.17.11
# 4    xOjlzuWakD4      CA      17.17.11
# ..           ...     ...           ...
# 176  V6ElE2xs48c      US      18.02.06
# 177  V6ElE2xs48c      US      18.03.06
# 178  V6ElE2xs48c      US      18.04.06
# 179  V6ElE2xs48c      US      18.05.06
# 180  V6ElE2xs48c      US      18.06.06
#
#                                                  title    channel_title  \
# 0                    Deivamagal Episode 1388, 14/11/17        VikatanTV
# 1    Слуга Народа 2 - От любви до импичмента, 22 се...     Слуга народа
# 2    Слуга Народа 2 - От любви до импичмента, 23 серия     Слуга народа
# 3                   Priyamanaval Episode 866, 16/11/17        VikatanTV
# 4    Слуга Народа 2 - От любви до импичмента, 24 серия     Слуга народа
# ...
